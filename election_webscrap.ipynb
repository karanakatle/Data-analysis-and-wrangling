# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
from fake_useragent import UserAgent
import urllib.request as urb
import unidecode
import requests
from time import sleep
import re
import traceback
import sys
import time
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException

# %%
df=pd.read_excel('election.xlsx')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#           candidate_name candidate_party constituency
# 0          Captain Beany     Independent     Aberavon
# 1        Stephen Kinnock          Labour     Aberavon
# 2    Glenda Marie Davies          Brexit     Aberavon
# 3  Sheila Kingston-Jones              LD     Aberavon
# 4      Nigel Thomas Hunt     Plaid Cymru     Aberavon

# %%
cand=df.candidate_name.to_list()

# %%
party=df.candidate_party.to_list()

# %%
const=df.constituency.to_list()

# %%
name=[]
for x in cand:
    new_x=x.split()
    if len(new_x)>2:
        name.append(new_x[0].lstrip()+' '+new_x[2].rstrip())
    else:
        name.append((' '.join(new_x)).strip())

# %%
def get_data(var):
    
    ua = UserAgent()
    header = {'User-Agent':str(ua.Firefox)}
    browser.get(url)
    
    cand_name=[]
    cand_party=[]
    cand_cons=[]
    vote_share=[]
    total_reported_spending=[]
    electorate_figure=[]
    spending_limit=[]
    spending_limit_percent=[]
    direct_spending=[]
    national_spending=[]
    unpaid_claims=[]
    disputed_claims=[]
    advertising=[]
    unsolicited_material=[]
    transport=[]
    public_meeting=[]
    agent_staff=[]
    accomodation=[]
    personal_expenses=[]
    donations_accepted=[]
    
   
    inp_path='/html/body/div[2]/div[2]/div/main/article/div[3]/div[2]/div[2]/div/div/div/div[1]/section/div/div/div/div/div[1]/div[2]/div/div/div/div[1]/div/form/input'
    inp=browser.find_element_by_xpath(inp_path)
    inp.send_keys(var)
    click_path='/html/body/div[2]/div[2]/div/main/article/div[3]/div[2]/div[2]/div/div/div/div[1]/section/div/div/div/div/div[1]/div[2]/div/div/div/div[1]/div/ul'
    cur=browser.find_element_by_xpath(click_path)
    WebDriverWait(browser, 10).until(expected_conditions.element_to_be_clickable((By.XPATH, click_path)))
    browser.execute_script("arguments[0].scrollIntoView(true);", cur)
    time.sleep(10)
    detail_path='/html/body/div[2]/div[2]/div/main/article/div[3]/div[2]/div[2]/div/div/div/div[1]/section/div/div/div/div/div[1]/div[2]/div/div/div/div[1]/div/ul/li'
    detail=browser.find_element_by_xpath(detail_path)
    WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, detail_path)))
    browser.execute_script("arguments[0].scrollIntoView(true);", detail)
    details=detail.text.split('\n')
    cand_name.append(details[0])
    cand_party.append(details[1])
    cand_cons.append(details[2])
    WebDriverWait(browser, 10).until(expected_conditions.element_to_be_clickable((By.XPATH, click_path)))
    browser.execute_script("arguments[0].scrollIntoView(true);", cur)
    cur.click()
    
    filt_path='/html/body/div[2]/div[2]/div/main/article/div[3]/div[2]/div[2]/div/div/div/div[1]/section/div/div/div/div/div/div[3]/div/button'
    filt=browser.find_element_by_xpath(filt_path)
    filt.click()
    
    time.sleep(3)
    
    try:
        for i in [4,5,7,8,9,11]:
            selector='button.electoral-expenses-viz-RadioButton__button___15D2Z:nth-child({})'
            base_selector=selector.format(i)
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.CSS_SELECTOR, base_selector)))
            sel=browser.find_element_by_css_selector(base_selector)
            browser.execute_script("arguments[0].scrollIntoView(true);", sel)
            sel.click()
    except TimeoutException:
        pass

    for i in range(1,18):
        base_path='/html/body/div[2]/div[2]/div/main/article/div[3]/div[2]/div[2]/div/div/div/div[1]/section/div/div/div/div/div/div[4]/div/div[{}]/div[2]/div/div/div/div'
        path=base_path.format(i)
        if i==1:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                vote_share.append('NaN')
            else:
                vote_share.append(x)
        elif i==2:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                total_reported_spending.append('NaN')
            else:
                total_reported_spending.append(x)
        elif i==3:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                electorate_figure.append('NaN')
            else:
                electorate_figure.append(x)
        elif i==4:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                spending_limit.append('NaN')
            else:
                spending_limit.append(x)
        elif i==5:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                spending_limit_percent.append('NaN')
            else:
                spending_limit_percent.append(x)
        elif i==6:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                direct_spending.append('NaN')
            else:
                direct_spending.append(x)
        elif i==7:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                national_spending.append('NaN')
            else:
                national_spending.append(x)
        elif i==8:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                unpaid_claims.append('NaN')
            else:
                unpaid_claims.append(x)
        elif i==9:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                disputed_claims.append('NaN')
            else:
                disputed_claims.append(x)
        elif i==10:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                advertising.append('NaN')
            else:
                advertising.append(x)
        elif i==11:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                unsolicited_material.append('NaN')
            else:
                unsolicited_material.append(x)
        elif i==12:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                transport.append('NaN')
            else:
                transport.append(x)
        elif i==13:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                public_meeting.append('NaN')
            else:
                public_meeting.append(x)
        elif i==14:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                agent_staff.append('NaN')
            else:
                agent_staff.append(x)
        elif i==15:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                accomodation.append('NaN')
            else:
                accomodation.append(x)
        elif i==16:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                personal_expenses.append('NaN')
            else:
                personal_expenses.append(x)
        else:
            z=browser.find_element_by_xpath(path)
            x=z.text.lstrip('£').rstrip('%')
            WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, path)))
            browser.execute_script("arguments[0].scrollIntoView(true);", z)
            if re.search('[a-zA-Z]',x):
                donations_accepted.append('NaN')
            else:
                donations_accepted.append(x)
                
                
    clear_path='/html/body/div[2]/div[2]/div/main/article/div[3]/div[2]/div[2]/div/div/div/div[1]/section/div/div/div/div/div/div[5]/div[2]/button[2]'
    WebDriverWait(browser, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, clear_path)))
    clearing=browser.find_element_by_xpath(clear_path)
    browser.execute_script("arguments[0].scrollIntoView(true);", clearing)
    clearing.click()
        
                    
    table=pd.DataFrame({'cand_name':cand_name,
                        'cand_party':cand_party,
                        'cand_cons':cand_cons,
                        'vote_share':vote_share,
                        'total_reported_spending':total_reported_spending,
                        'electorate_figure':electorate_figure,
                        'spending_limit':spending_limit,
                        'spending_limit_percent':spending_limit_percent,
                        'direct_spending':direct_spending,
                        'national_spending':national_spending,
                        'unpaid_claims':unpaid_claims,
                        'disputed_claims':disputed_claims,
                        'advertising':advertising,
                        'unsolicited_material':unsolicited_material,
                        'transport':transport,
                        'public_meeting':public_meeting,
                        'agent_staff':agent_staff,
                        'accomodation':accomodation,
                        'personal_expenses':personal_expenses,
                        'donations_accepted':donations_accepted})

    return table

# %%
url='https://www.electoralcommission.org.uk/2019-candidate-spending?section=filter&national_values=&filters=%255B%255D'

# %%
browser=webdriver.Firefox()

# %%
tables=[]
count=0
for var in tqdm(name):
    try:
        tables.append(get_data(var))
    except NoSuchElementException:
        try:
            tables.append(get_data(cand[count]))
        except NoSuchElementException:
            continue
    count+=1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 502/502 [2:37:10<00:00, 18.79s/it]

# %%
big_table=pd.concat(tables,axis=0)

# %%
big_table.reset_index(drop=True,inplace=True)

# %%
big_table.head()
# Out:
#                cand_name             cand_party cand_cons vote_share  \
# 0          Captain Beany  Independent and Other  Aberavon       2.31
# 1        Stephen Kinnock           Labour Party  Aberavon      53.83
# 2          Glenda Davies           Brexit Party  Aberavon       9.84
# 3  Sheila Kingston-Jones      Liberal Democrats  Aberavon       3.39
# 4             Nigel Hunt            Plaid Cymru  Aberavon       8.58
#
#   total_reported_spending electorate_figure spending_limit  \
# 0                   50.00                 7            NaN
# 1               12,509.28            50,750      13,136.91
# 2                4,933.78            50,747      13,136.91
# 3                  225.67               NaN      13,136.91
# 4                1,515.00            50,750      13,136.91
#
#   spending_limit_percent direct_spending national_spending unpaid_claims  \
# 0                    NaN           50.00              0.00          0.00
# ...

# %%
big_table.to_csv('electoralcom_uk.csv',index=False)
